# %% [markdown]
# #EXERCISE1

# %%
# !pip install pandas
# !pip install matplotlib

# %% [markdown]
# ##FUNCTIONS

# %%
def myname():
    print("Ivan")

# %%
myname()
# Out:
# Ivan

# %%
def mysurname(surname):
    print(surname)

# %%
mysurname("Calangan")
# Out:
# Calangan

# %%
def fullname(fname, lname):
  print(fname,lname)

# %%
fullname ("Ivan","Calangan")
# Out:
# Ivan Calangan

# %%
def completename(*fullname):
    print(fullname)

# %%
completename("Calangan","Tadina", "Ivan")
# Out:
# ('Calangan', 'Tadina', 'Ivan')

# %%
name = "ivan"

lname : str = 1234

lname
# Out:
# 1234

# %%
def mynumber(num : int):
    print(num)

# %%
mynumber(5)
# Out:
# 5

# %%
def myletter(letter : str):
    return letter

# %% [markdown]
# ##Lists

# %%
fruits = ["apple","banana", "orange", "lemon", "grapes"]

# %%
fruits
# Out:
# ['apple', 'banana', 'orange', 'lemon', 'grapes']

# %%
for i in fruits:
    print(i)
# Out:
# apple
# banana
# orange
# lemon
# grapes

# %%
mynewlist = []

for i in fruits:
    mynewlist.append(i)

# %%
mynewlist
# Out:
# ['apple', 'banana', 'orange', 'lemon', 'grapes']

# %% [markdown]
# list comprehension

# %%
mynewlist = [x for x in fruits]

# %%
mynewlist
# Out:
# ['apple', 'banana', 'orange', 'lemon', 'grapes']

# %%
mynewlist2 = [x for x in fruits if "e" in x]
mynewlist2
# Out:
# ['apple', 'orange', 'lemon', 'grapes']

# %% [markdown]
# ##MAP

# %%
mynumbers = [1,2,3,4,5]

# %%
def multiplybytwo(num):
    return num*2

# %%
mynewnumbers = list(map(multiplybytwo, mynumbers))
mynewnumbers
# Out:
# [2, 4, 6, 8, 10]

# %% [markdown]
# ##LAMBDA

# %%
answer = lambda x: x*7
print(answer(5))
# Out:
# 35

# %% [markdown]
# #PANDAS

# %%
import pandas as pd

# %%
dataframe = pd.read_excel("Book1.xlsx")

# %%
dataframe
# Out:
#    height  weight  age
# 0     181      95   20
# 1     179      80   21
# 2     174      75   21
# 3     184      85   18
# 4     175      83   19
# 5     178      79   27
# 6     169      88   22
# 7     183      60   21
# 8     172      68   19
# 9     172      64   20

# %%
dataframe.head()
# Out:
#    height  weight  age
# 0     181      95   20
# 1     179      80   21
# 2     174      75   21
# 3     184      85   18
# 4     175      83   19

# %%
dataframe.tail()
# Out:
#    height  weight  age
# 5     178      79   27
# 6     169      88   22
# 7     183      60   21
# 8     172      68   19
# 9     172      64   20

# %%
dataframe.value_counts()
# Out:
# height  weight  age
# 169     88      22     1
# 172     64      20     1
#         68      19     1
# 174     75      21     1
# 175     83      19     1
# 178     79      27     1
# 179     80      21     1
# 181     95      20     1
# 183     60      21     1
# 184     85      18     1
# Name: count, dtype: int64

# %%
dataframe.value_counts()
# Out:
# height  weight  age
# 169     88      22     1
# 172     64      20     1
#         68      19     1
# 174     75      21     1
# 175     83      19     1
# 178     79      27     1
# 179     80      21     1
# 181     95      20     1
# 183     60      21     1
# 184     85      18     1
# Name: count, dtype: int64

# %%
dataframe = pd.read_excel("Book2.xlsx")
dataframe
# Out:
#     height  weight  age
# 0      181      95   20
# 1      179      80   21
# 2      174      75   21
# 3      184      85   18
# 4      175      83   19
# 5      178      79   27
# 6      169      88   22
# 7      183      60   21
# 8      172      68   19
# 9      172      64   20
# 10     169      88   22

# %%
dataframe.value_counts()
# Out:
# height  weight  age
# 169     88      22     2
# 172     64      20     1
#         68      19     1
# 174     75      21     1
# 175     83      19     1
# 178     79      27     1
# 179     80      21     1
# 181     95      20     1
# 183     60      21     1
# 184     85      18     1
# Name: count, dtype: int64

# %%
dataframe.drop_duplicates(inplace=True)
dataframe.value_counts()
# Out:
# height  weight  age
# 169     88      22     1
# 172     64      20     1
#         68      19     1
# 174     75      21     1
# 175     83      19     1
# 178     79      27     1
# 179     80      21     1
# 181     95      20     1
# 183     60      21     1
# 184     85      18     1
# Name: count, dtype: int64

# %%
dataframe.iloc[0]
# Out:
# height    181
# weight     95
# age        20
# Name: 0, dtype: int64

# %%
dataframe.describe()
# Out:
#            height   weight        age
# count   10.000000  10.0000  10.000000
# mean   176.700000  77.7000  20.800000
# std      5.078276  11.0358   2.485514
# min    169.000000  60.0000  18.000000
# 25%    172.500000  69.7500  19.250000
# 50%    176.500000  79.5000  20.500000
# 75%    180.500000  84.5000  21.000000
# max    184.000000  95.0000  27.000000

# %%
dataframe.shape
# Out:
# (10, 3)

# %%
dataframe.drop(columns=["age"], inplace=True)

# %%
dataframe
# Out:
#    height  weight
# 0     181      95
# 1     179      80
# 2     174      75
# 3     184      85
# 4     175      83
# 5     178      79
# 6     169      88
# 7     183      60
# 8     172      68
# 9     172      64

# %% [markdown]
# ##matplotlib

# %%
from matplotlib import pyplot as plt

# %%
X1 = [1,2,3,4,5]

# %%
plt.plot(X1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
X2 = [6,7,8,9,10]
plt.plot(X1)
plt.plot(X2)
plt.show()

# %%
Y = [10,11,12,13,14]

plt.plot(X1,Y)
plt.show()

# %%
Y = [10,11,12,13,14]

plt.plot(X1,Y, marker = "o", color = "pink", linestyle = "dotted")
plt.show()

# %%
Y = [10,11,12,13,14]

plt.plot(X1,Y, marker = "o", color = "pink", linestyle = "dotted")
plt.grid()
plt.show()

# %%
Y = [10,11,12,13,14]

plt.plot(X1,Y, marker = "o", color = "pink", linestyle = "dotted")
plt.grid()
plt.show()

# %%
Y = [10,11,12,13,14]

plt.plot(X1,Y, marker = "o", color = "pink", linestyle = "dotted")
plt.title("BOSSING!")
plt.xlabel("X AXIS")
plt.ylabel("Y AXIS")
plt.grid() ##axis= 'x','y'
plt.show()

# %%
plt.plot(dataframe['height'],dataframe['weight'], marker = "o", color = "pink", linestyle = "dotted")
plt.title("BOSSING!")
plt.xlabel("height")
plt.ylabel("weight")
plt.grid()
plt.show()
